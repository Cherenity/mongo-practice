# %%
full_name = "Muru"
email = "Pallero"
age = 3
  
person = {
  "name" : full_name, 
  "email" : email, 
  "age" : age
  }


person_summary = (
  f"Add a new person:\n"
  f"{'Name':<5}: {person['name']}\n"
  f"{'Email':<5}: {person['email']}\n"
  f"{'Age':<5}: {person['age']}"
)

print(person_summary)
# Out:
# Add a new person:
# Name : Muru
# Email: Pallero
# Age  : 3
